# %%
import os
import tensorflow as tf
import tensorflow.contrib.eager as tfe
import numpy as np
import math
import timeit
import matplotlib.pyplot as plt
import scipy.misc
import pickle

# %matplotlib inline

# %%
tf.enable_eager_execution()

# %%
def load_cifar10(num_training=49000, num_validation=1000, num_test=10000):
    """
    Fetch the CIFAR-10 dataset from the web and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.
    """
    # Load the raw CIFAR-10 dataset and use appropriate data types and shapes
    cifar10 = tf.keras.datasets.cifar10.load_data()
    (X_train, y_train), (X_test, y_test) = cifar10
    X_train = np.asarray(X_train, dtype=np.float32)
    y_train = np.asarray(y_train, dtype=np.int32).flatten()
    X_test = np.asarray(X_test, dtype=np.float32)
    y_test = np.asarray(y_test, dtype=np.int32).flatten()

    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean pixel and divide by std
    mean_pixel = X_train.mean(axis=(0, 1, 2), keepdims=True)
    std_pixel = X_train.std(axis=(0, 1, 2), keepdims=True)
    X_train = (X_train - mean_pixel) / std_pixel
    X_val = (X_val - mean_pixel) / std_pixel
    X_test = (X_test - mean_pixel) / std_pixel

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
NHW = (0, 1, 2)
X_train, y_train, X_val, y_val, X_test, y_test = load_cifar10()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape, y_train.dtype)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)

# %%
def resize_datasets(X):
    X_new = []
    for i in range(X.shape[0]):
        if(i % 100 == 0):
            print(i)
        img = scipy.ndimage.interpolation.zoom(X[i], (8.0, 8.0, 1.0))
        X_new.append(img)
    X_new = np.asarray(X_new, dtype=np.float32)
    return X_new.reshape([X.shape[0], 256, 256, 3])

# %%
print('Resizing Validation...')
X_val = resize_datasets(X_val)

# %%
print('Resizing Test...')
X_test = resize_datasets(X_test)

# %%
print('Resizing Training...')
X_train = resize_datasets(X_train)

# %%
X_train.shape

# %%
pickle_out = open("train_dataset.pickle","wb")
pickle.dump(X_test, pickle_out)
pickle_out.close()

# %%
pickle_in = open("validation_dataset.pickle","rb")
X_val = pickle.load(pickle_in)

# %%
import pickle
pickle_in = open("dataset.pickle","rb")
X_train = pickle.load(pickle_in)
y_train = pickle.load(pickle_in)
X_test = pickle.load(pickle_in)
y_test = pickle.load(pickle_in)
X_val = pickle.load(pickle_in)
y_val = pickle.load(pickle_in)

# %%
X_test[:30] = X_train[:30]
y_test[:30] = y_train[:30]

# %%
training_set_size = 200
test_set_size = 100
valid_set_size = 50

# %%
class Dataset(object):
    def __init__(self, X, y, batch_size, shuffle=False):
        """
        Construct a Dataset object to iterate over data X and labels y
        
        Inputs:
        - X: Numpy array of data, of any shape
        - y: Numpy array of labels, of any shape but with y.shape[0] == X.shape[0]
        - batch_size: Integer giving number of elements per minibatch
        - shuffle: (optional) Boolean, whether to shuffle the data on each epoch
        """
        assert X.shape[0] == y.shape[0], 'Got different numbers of data and labels'
        self.X, self.y = X, y
        self.batch_size, self.shuffle = batch_size, shuffle

    def __iter__(self):
        N, B = self.X.shape[0], self.batch_size
        idxs = np.arange(N)
        if self.shuffle:
            np.random.shuffle(idxs)
        return iter((self.X[i:i+B], self.y[i:i+B]) for i in range(0, N, B))

# %%
def flatten(x):
    """    
    Input:
    - TensorFlow Tensor of shape (N, D1, ..., DM)
    
    Output:
    - TensorFlow Tensor of shape (N, D1 * ... * DM)
    """
    N = tf.shape(x)[0]
    return tf.reshape(x, (N, -1))

# %%
inp = tf.get_variable(name = 'input', shape=[1,256,256,3], dtype=tf.float32)

# %%
#globals used in the assignment
IMG_SHAPE = [256, 256, 3] # height, width, channels
NUM_CLASSES = 10

# training hyperparameters
LEARNING_RATE = 1e-4
MOMENTUM = 0.9
BATCH_SIZE = 16
EPOCHS = 30
DISPLAY_STEP = 1
VALIDATION_STEP = 1000
SAVE_STEP = 1000
CKPT_PATH = './ckpt'
SUMMARY_PATH = './summary'

# net architecture hyperparamaters
LAMBDA = 5e-4 #for weight decay
DROPOUT = 0.5

# test hyper parameters
K_PATCHES = 5
TOP_K = 5

# %%
class AlexNet(tfe.Network):
    def __init__(self, training):
        super(AlexNet, self).__init__()
        self.training = training
        
        # convolutional layers
        conv_init = tf.contrib.layers.xavier_initializer_conv2d()
        
        self.conv1 = self.track_layer(
            tf.layers.Conv2D(
                96,
                11,
                4,
                'SAME',
                activation=tf.nn.relu,
                kernel_initializer=conv_init))
        self.pool1 = self.track_layer(tf.layers.MaxPooling2D(3, 2, 'VALID'))

        self.conv2 = self.track_layer(
            tf.layers.Conv2D(
                256,
                5,
                1,
                'SAME',
                activation=tf.nn.relu,
                kernel_initializer=conv_init))
        self.pool2 = self.track_layer(tf.layers.MaxPooling2D(3, 2, 'VALID'))

        self.conv3 = self.track_layer(
            tf.layers.Conv2D(
                384,
                3,
                1,
                'SAME',
                activation=tf.nn.relu,
                kernel_initializer=conv_init))

        self.conv4 = self.track_layer(
            tf.layers.Conv2D(
                384,
                3,
                1,
                'SAME',
                activation=tf.nn.relu,
                kernel_initializer=conv_init))

        self.conv5 = self.track_layer(
            tf.layers.Conv2D(
                256,
                3,
                1,
                'SAME',
                activation=tf.nn.relu,
                kernel_initializer=conv_init))
        self.pool5 = self.track_layer(tf.layers.MaxPooling2D(3, 2, 'VALID'))

        # fully connected layers

        fc_init = tf.contrib.layers.xavier_initializer()

        self.fc1 = self.track_layer(
            tf.layers.Dense(
                512, kernel_initializer=fc_init))
        self.drop1 = self.track_layer(tf.layers.Dropout(DROPOUT))
        
        #attention estimators
        self.atten1_fc = self.track_layer(
            tf.layers.Dense(
                512, kernel_initializer=fc_init))
        
        self.atten2_fc = self.track_layer(
            tf.layers.Dense(
                512, kernel_initializer=fc_init))
        
        self.out1 = self.track_layer(
            tf.layers.Dense(NUM_CLASSES, activation=tf.nn.softmax, kernel_initializer=fc_init))
        
        self.out2 = self.track_layer(
            tf.layers.Dense(NUM_CLASSES, activation=tf.nn.softmax, kernel_initializer=fc_init))

    def call(self, x):
        """ Function that executes the model """
        output = self.conv1(x)
        #print("After conv1 : " + str(output.numpy().shape))
        output = tf.nn.lrn(
            output, depth_radius=2, bias=1.0, alpha=2e-05, beta=0.75)
        #print("After normalisation1 : " + str(output.numpy().shape))
        output = self.pool1(output)
        #print("After pool1 : " + str(output.numpy().shape))

        output = self.conv2(output)
        #print("After conv2 : " + str(output.numpy().shape))
        output = tf.nn.lrn(
            output, depth_radius=2, bias=1.0, alpha=2e-05, beta=0.75)
        #print("After normalisation2 : " + str(output.numpy().shape))
        output = self.pool2(output)
        #print("After pool2 : " + str(output.numpy().shape))

        output = self.conv3(output)
        #print("After conv3 : " + str(output.numpy().shape))

        output = self.conv4(output)
        #print("After conv4 : " + str(output.numpy().shape))
        conv4_output = output

        output = self.conv5(output)
        #print("After conv5 : " + str(output.numpy().shape))
        conv5_output = output
        
        output = self.pool5(output)
        #print("After pool5 : " + str(output.numpy().shape))

        output = tf.layers.flatten(output)
        #print("After flattening : " + str(output.numpy().shape))

        output = self.fc1(output)
        #print("After fc1 : " + str(output.numpy().shape))
        if self.training:
            output = self.drop1(output)
            #print("After drop1 : " + str(output.numpy().shape))
        
#         logic for attention estimators
        g = tf.reshape(output, (output.shape[0], output.shape[1], 1))
#         print("G dimensions : " + str(g.numpy().shape))
        
#         print("\nATTENTION 1 :-")
        atten1_flattened_output = tf.reshape(conv4_output, (conv4_output.shape[0], conv4_output.shape[1] * conv4_output.shape[2], conv4_output.shape[3]))
#         print("After Flattening : " + str(atten1_flattened_output.numpy().shape))
        atten1_output = self.atten1_fc(atten1_flattened_output)
#         print("After FC : " + str(atten1_output.numpy().shape))
        atten1_output = tf.matmul(atten1_output, g)
#         print("After Dot Product with G : " + str(atten1_output.numpy().shape))
        atten1_output = tf.reshape(atten1_output, (atten1_output.shape[0], atten1_output.shape[2], atten1_output.shape[1]))
        attention1_value = atten1_output
        atten1_output = tf.nn.softmax(atten1_output)
#         print("After Reshaping and applying Softmax : " + str(atten1_output.numpy().shape))
        atten1_output = tf.matmul(atten1_output, atten1_flattened_output)
#         print("G_a1 Dimensions : " + str(atten1_output.numpy().shape))
        
#         print("\nATTENTION 2 :-")
        atten2_flattened_output = tf.reshape(conv5_output, (conv5_output.shape[0], conv5_output.shape[1] * conv5_output.shape[2], conv5_output.shape[3]))
#         print("After Flattening : " + str(atten2_flattened_output.numpy().shape))
        atten2_output = self.atten2_fc(atten2_flattened_output)
#         print("After FC : " + str(atten2_output.numpy().shape))
        atten2_output = tf.matmul(atten2_output, g)
#         print("After Dot Product with G : " + str(atten2_output.numpy().shape))
        atten2_output = tf.reshape(atten2_output, (atten2_output.shape[0], atten2_output.shape[2], atten2_output.shape[1]))
        attention2_value = atten2_output
        atten2_output = tf.nn.softmax(atten2_output)
#         print("After Reshaping and applying Softmax : " + str(atten2_output.numpy().shape))
        atten2_output = tf.matmul(atten2_output, atten2_flattened_output)
#         print("G_a2 Dimensions : " + str(atten2_output.numpy().shape))
        
#         print("\nCOMBINING BY OPTION 2 :-")
        output1 = tf.reshape(atten1_output, (atten1_output.shape[0], atten1_output.shape[2]))
#         print("Output1 Dimensions : " + str(output1.numpy().shape))
        output1 = self.out1(output1)
#         print("Output1 Dimensions : " + str(output1.numpy().shape))
        
        output2 = tf.reshape(atten2_output, (atten2_output.shape[0], atten2_output.shape[2]))
#         print("Output2 Dimensions : " + str(output2.numpy().shape))
        output2 = self.out2(output2)
#         print("Output2 Dimensions : " + str(output2.numpy().shape))
        
        output = tf.reduce_mean([output1, output2], 0)
        return output,attention1_value, attention2_value

# %%
def loss(net, mode, x, y):
    """
    Computes the loss for a given batch of examples
    Args:
        mode, string 'train' or 'val'
        x, tf tensor representing a batch of images
        y, tf tensor representing a batch of labels
    Returns:
        the loss between the predictions on the images and the groundtruths
    """
    pred = net(x)[0]
    scaled_y = tf.one_hot(y, NUM_CLASSES)

#     print(tf.log(pred).numpy().shape)
#     print(scaled_y.numpy().shape)
#     print(tf.reduce_sum(scaled_y * tf.log(pred), reduction_indices=[1]).numpy().shape)
    
    loss_value = tf.reduce_mean(-tf.reduce_sum(scaled_y * tf.log(pred), reduction_indices=[1]))
    
    weight_decay = tf.reduce_sum(LAMBDA * tf.stack([tf.nn.l2_loss(v) for v in net.variables]))

    total_loss = loss_value + weight_decay

    tf.contrib.summary.scalar(mode + '/loss', total_loss)

    return total_loss

# %%
def accuracy(net, mode, x, y):
    """
    Computes the accuracy for a given batch of examples
    Args:
        mode, string 'train' or 'val'
        x, tf tensor representing a batch of images
        y, tf tensor representing a batch of labels
    Returns:
        the accuracy of the predictions on the images and the groundtruths
    """
#     pred = tf.nn.softmax(net(x))
    pred = net(x)[0]
    y = tf.one_hot(y, NUM_CLASSES)

    accuracy_value = tf.reduce_sum(
                tf.cast(
                    tf.equal(
                        tf.argmax(pred, axis=1, output_type=tf.int64),
                        tf.argmax(y, axis=1, output_type=tf.int64)
                    ),
                    dtype=tf.float32
                ) 
            ) / float(pred.shape[0].value)

    tf.contrib.summary.scalar(mode +'/accuracy', accuracy_value)

    return accuracy_value

# %%
train_dset = Dataset(X_train, y_train, batch_size=BATCH_SIZE, shuffle=True)
val_dset = Dataset(X_val, y_val, batch_size=valid_set_size, shuffle=False)
test_dset = Dataset(X_test, y_test, batch_size=test_set_size)

# %%
# We can iterate through a dataset like this:
for t, (x, y) in enumerate(train_dset):
    print(t, x.shape, y.shape)
#     print(y)
    if t > 5: break
# Out:
# 0 (16, 256, 256, 3) (16,)
# 1 (16, 256, 256, 3) (16,)
# 2 (16, 256, 256, 3) (16,)
# 3 (16, 256, 256, 3) (16,)
# 4 (16, 256, 256, 3) (16,)
# 5 (16, 256, 256, 3) (16,)
# 6 (16, 256, 256, 3) (16,)

# %%
img = X_val[1,:]
img = tf.to_float(img.reshape([1,256,256,3]))

# %%
trainingset = Dataset(X_val[:8], y_val[:8], batch_size=BATCH_SIZE, shuffle=False)

# %%
#used for printing the log with the timestamp
logging = tf.logging
logging.set_verbosity(logging.INFO)
def log_msg(msg):
       logging.info(f'{time.ctime()}: {msg}')

# %%
DISPLAY_STEP = 1
VALIDATION_STEP = 5
SAVE_STEP = 10

# %%
import time
def train(net):
    """
    Training procedure
    """
    start_time = time.time()
    step_time = 0.0
    
    writer = tf.contrib.summary.create_summary_file_writer(SUMMARY_PATH)
#     optimizer = tf.train.MomentumOptimizer(learning_rate=LEARNING_RATE, momentum=MOMENTUM)
    optimizer = tf.train.AdamOptimizer(learning_rate = LEARNING_RATE)
    global_step = tf.train.get_or_create_global_step()
    epoch = tfe.Variable(0, name='epoch', dtype=tf.float32, trainable=False)
    all_variables = (net.variables + optimizer.variables() + [global_step] + [epoch])
    
    with writer.as_default():
        with tf.contrib.summary.record_summaries_every_n_global_steps(DISPLAY_STEP):
            for e in range(int(epoch.numpy()), EPOCHS):
                tf.assign(epoch, e)
                for (batch_i, (images, labels)) in enumerate(train_dset):
                    global_step = tf.train.get_global_step()
                    step = global_step.numpy() + 1
                    images = tf.to_float(images)
                    step_start_time = int(round(time.time() * 1000))
                    
                    optimizer.minimize(lambda: loss(net, 'train', images, labels), global_step=global_step)

                    step_end_time = int(round(time.time() * 1000))
                    step_time += step_end_time - step_start_time

                    if (step % DISPLAY_STEP) == 0:
                        l = loss(net, 'train', images, labels)
                        a = accuracy(net, 'train', images, labels).numpy()
                        log_msg('Epoch: {:03d} Step/Batch: {:09d} Step mean time: {:04d}ms \nLoss: {:.7f} Training accuracy: {:.4f}'.format(e, step, int(step_time / step), l, a))

                    if (step % VALIDATION_STEP) == 0:
                        for (_, (val_images, val_labels)) in enumerate(val_dset):
#                             val_images, val_labels = tfe.Iterator(val_dset).next()
                            l = loss(net, 'val', val_images, val_labels)
                            a = accuracy(net, 'val', val_images, val_labels).numpy()
                            int_time = time.time() - start_time
                            log_msg('Elapsed time: {:04d}ms --- Loss: {:.7f} Validation accuracy: {:.4f}'.format(int(int_time), l, a))

                    if (step % SAVE_STEP) == 0:
                        tfe.Saver(net.variables).save(os.path.join(CKPT_PATH, 'net.ckpt'), global_step=global_step)
                        log_msg('Variables saved')

# %%
alexnet = AlexNet(training=True)
# Out:
# WARNING:tensorflow:From <ipython-input-9-937bdc8dbfe2>:3: Network.__init__ (from tensorflow.contrib.eager.python.network) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please inherit from `tf.keras.Model`, and see its documentation for details. `tf.keras.Model` should be a drop-in replacement for `tfe.Network` in most cases, but note that `track_layer` is no longer necessary or supported. Instead, `Layer` instances are tracked on attribute assignment (see the section of `tf.keras.Model`'s documentation on subclassing). Since the output of `track_layer` is often assigned to an attribute anyway, most code can be ported by simply removing the `track_layer` calls.
#
# `tf.keras.Model` works with all TensorFlow `Layer` instances, including those from `tf.layers`, but switching to the `tf.keras.layers` versions along with the migration to `tf.keras.Model` is recommended, since it will preserve variable names. Feel free to import it with an alias to avoid excess typing :).
# WARNING:tensorflow:** tfe.Network is deprecated and will be removed in a future version.
#
# Please inherit from `tf.keras.Model`, and see its documentation for details. `tf.keras.Model` should be a drop-in replacement for `tfe.Network` in most cases, but note that `track_layer` is no longer necessary or supported. Instead, `Layer` instances are tracked on attribute assignment (see the section of `tf.keras.Model`'s documentation on subclassing). Since the output of `track_layer` is often assigned to an attribute anyway, most code can be ported by simply removing the `track_layer` calls.
#
# `tf.keras.Model` works with all TensorFlow `Layer` instances, including those from `tf.layers`, but switching to the `tf.keras.layers` versions along with the migration to `tf.keras.Model` is recommended, since it will preserve variable names. Feel free to import it with an alias to avoid excess typing :).

# %%
if not os.path.exists(CKPT_PATH):
    os.makedirs(CKPT_PATH)
train(alexnet)
# Out:
# WARNING:tensorflow:Deprecation Warning: create_summary_file_writer was renamed to create_file_writer
# INFO:tensorflow:Sat Nov 17 21:51:54 2018: Epoch: 000 Step/Batch: 000000001 Step mean time: 2371ms
# Loss: 2.9288161 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:51:57 2018: Epoch: 000 Step/Batch: 000000002 Step mean time: 2230ms
# Loss: 3.0147622 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 21:52:01 2018: Epoch: 000 Step/Batch: 000000003 Step mean time: 2189ms
# Loss: 3.0309825 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 21:52:04 2018: Epoch: 000 Step/Batch: 000000004 Step mean time: 2172ms
# Loss: 3.0211687 Training accuracy: 0.0000
# INFO:tensorflow:Sat Nov 17 21:52:07 2018: Epoch: 000 Step/Batch: 000000005 Step mean time: 2166ms
# Loss: 3.0174546 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 21:52:11 2018: Elapsed time: 0020ms --- Loss: 3.0150080 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 21:52:15 2018: Epoch: 000 Step/Batch: 000000006 Step mean time: 2177ms
# Loss: 3.0207701 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:52:18 2018: Epoch: 000 Step/Batch: 000000007 Step mean time: 2170ms
# Loss: 2.9466298 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:52:22 2018: Epoch: 000 Step/Batch: 000000008 Step mean time: 2200ms
# Loss: 3.0398481 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 21:52:25 2018: Epoch: 000 Step/Batch: 000000009 Step mean time: 2199ms
# Loss: 2.9886045 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 21:52:29 2018: Epoch: 000 Step/Batch: 000000010 Step mean time: 2200ms
# Loss: 2.9828176 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 21:52:33 2018: Elapsed time: 0042ms --- Loss: 2.9878261 Validation accuracy: 0.1400
# INFO:tensorflow:Sat Nov 17 21:52:33 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 21:52:37 2018: Epoch: 000 Step/Batch: 000000011 Step mean time: 2206ms
# Loss: 2.9784646 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 21:52:43 2018: Epoch: 000 Step/Batch: 000000012 Step mean time: 2318ms
# Loss: 3.0065966 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 21:52:46 2018: Epoch: 000 Step/Batch: 000000013 Step mean time: 2291ms
# Loss: 2.9772539 Training accuracy: 0.0000
# INFO:tensorflow:Sat Nov 17 21:52:53 2018: Epoch: 001 Step/Batch: 000000014 Step mean time: 2412ms
# Loss: 2.9218111 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 21:52:59 2018: Epoch: 001 Step/Batch: 000000015 Step mean time: 2533ms
# Loss: 2.9530408 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 21:53:08 2018: Elapsed time: 0077ms --- Loss: 2.9496200 Validation accuracy: 0.1400
# INFO:tensorflow:Sat Nov 17 21:53:15 2018: Epoch: 001 Step/Batch: 000000016 Step mean time: 2656ms
# Loss: 2.9474459 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:53:21 2018: Epoch: 001 Step/Batch: 000000017 Step mean time: 2734ms
# Loss: 2.9378188 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 21:53:28 2018: Epoch: 001 Step/Batch: 000000018 Step mean time: 2804ms
# Loss: 2.9093416 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 21:53:34 2018: Epoch: 001 Step/Batch: 000000019 Step mean time: 2871ms
# Loss: 2.8934090 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:53:41 2018: Epoch: 001 Step/Batch: 000000020 Step mean time: 2930ms
# Loss: 2.8963671 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 21:53:49 2018: Elapsed time: 0118ms --- Loss: 2.8932438 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 21:53:49 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 21:53:55 2018: Epoch: 001 Step/Batch: 000000021 Step mean time: 2987ms
# Loss: 2.8258071 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:54:01 2018: Epoch: 001 Step/Batch: 000000022 Step mean time: 3026ms
# Loss: 2.8881299 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 21:54:08 2018: Epoch: 001 Step/Batch: 000000023 Step mean time: 3065ms
# Loss: 2.8090155 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 21:54:14 2018: Epoch: 001 Step/Batch: 000000024 Step mean time: 3100ms
# Loss: 2.7135763 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 21:54:20 2018: Epoch: 001 Step/Batch: 000000025 Step mean time: 3130ms
# Loss: 2.8440571 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 21:54:28 2018: Elapsed time: 0157ms --- Loss: 2.8064969 Validation accuracy: 0.2200
# INFO:tensorflow:Sat Nov 17 21:54:31 2018: Epoch: 001 Step/Batch: 000000026 Step mean time: 3090ms
# Loss: 2.5823276 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:54:37 2018: Epoch: 002 Step/Batch: 000000027 Step mean time: 3119ms
# Loss: 2.7973576 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 21:54:43 2018: Epoch: 002 Step/Batch: 000000028 Step mean time: 3145ms
# Loss: 2.8933237 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 21:54:49 2018: Epoch: 002 Step/Batch: 000000029 Step mean time: 3171ms
# Loss: 2.9747028 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 21:54:56 2018: Epoch: 002 Step/Batch: 000000030 Step mean time: 3194ms
# Loss: 2.8995597 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 21:55:03 2018: Elapsed time: 0192ms --- Loss: 2.7970948 Validation accuracy: 0.2000
# INFO:tensorflow:Sat Nov 17 21:55:03 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 21:55:10 2018: Epoch: 002 Step/Batch: 000000031 Step mean time: 3222ms
# Loss: 2.8223553 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:55:16 2018: Epoch: 002 Step/Batch: 000000032 Step mean time: 3243ms
# Loss: 2.7239802 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 21:55:22 2018: Epoch: 002 Step/Batch: 000000033 Step mean time: 3263ms
# Loss: 2.8243384 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:55:28 2018: Epoch: 002 Step/Batch: 000000034 Step mean time: 3280ms
# Loss: 2.7364883 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 21:55:35 2018: Epoch: 002 Step/Batch: 000000035 Step mean time: 3298ms
# Loss: 2.8314900 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 21:55:42 2018: Elapsed time: 0231ms --- Loss: 2.7821622 Validation accuracy: 0.2000
# INFO:tensorflow:Sat Nov 17 21:55:49 2018: Epoch: 002 Step/Batch: 000000036 Step mean time: 3322ms
# Loss: 2.7006547 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 21:55:55 2018: Epoch: 002 Step/Batch: 000000037 Step mean time: 3338ms
# Loss: 2.6918430 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 21:56:01 2018: Epoch: 002 Step/Batch: 000000038 Step mean time: 3354ms
# Loss: 2.7693124 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:56:04 2018: Epoch: 002 Step/Batch: 000000039 Step mean time: 3319ms
# Loss: 2.6232457 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 21:56:11 2018: Epoch: 003 Step/Batch: 000000040 Step mean time: 3336ms
# Loss: 2.6967578 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 21:56:18 2018: Elapsed time: 0267ms --- Loss: 2.7638600 Validation accuracy: 0.2200
# INFO:tensorflow:Sat Nov 17 21:56:18 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 21:56:25 2018: Epoch: 003 Step/Batch: 000000041 Step mean time: 3356ms
# Loss: 2.9174099 Training accuracy: 0.0000
# INFO:tensorflow:Sat Nov 17 21:56:31 2018: Epoch: 003 Step/Batch: 000000042 Step mean time: 3369ms
# Loss: 2.8119442 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 21:56:37 2018: Epoch: 003 Step/Batch: 000000043 Step mean time: 3383ms
# Loss: 2.7720795 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:56:44 2018: Epoch: 003 Step/Batch: 000000044 Step mean time: 3396ms
# Loss: 2.7839589 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:56:50 2018: Epoch: 003 Step/Batch: 000000045 Step mean time: 3409ms
# Loss: 2.7057199 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 21:56:57 2018: Elapsed time: 0307ms --- Loss: 2.8012950 Validation accuracy: 0.2200
# INFO:tensorflow:Sat Nov 17 21:57:04 2018: Epoch: 003 Step/Batch: 000000046 Step mean time: 3424ms
# Loss: 2.7857494 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 21:57:10 2018: Epoch: 003 Step/Batch: 000000047 Step mean time: 3437ms
# Loss: 2.6823568 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 21:57:16 2018: Epoch: 003 Step/Batch: 000000048 Step mean time: 3450ms
# Loss: 2.7826090 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 21:57:23 2018: Epoch: 003 Step/Batch: 000000049 Step mean time: 3460ms
# Loss: 2.5805209 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 21:57:29 2018: Epoch: 003 Step/Batch: 000000050 Step mean time: 3470ms
# Loss: 2.6152315 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 21:57:36 2018: Elapsed time: 0346ms --- Loss: 2.7592139 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 21:57:37 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 21:57:43 2018: Epoch: 003 Step/Batch: 000000051 Step mean time: 3482ms
# Loss: 2.7030985 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 21:57:46 2018: Epoch: 003 Step/Batch: 000000052 Step mean time: 3454ms
# Loss: 2.4591224 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 21:57:53 2018: Epoch: 004 Step/Batch: 000000053 Step mean time: 3465ms
# Loss: 2.5812101 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:57:59 2018: Epoch: 004 Step/Batch: 000000054 Step mean time: 3476ms
# Loss: 2.8451848 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 21:58:05 2018: Epoch: 004 Step/Batch: 000000055 Step mean time: 3485ms
# Loss: 2.6483519 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:58:13 2018: Elapsed time: 0382ms --- Loss: 2.7058868 Validation accuracy: 0.1400
# INFO:tensorflow:Sat Nov 17 21:58:19 2018: Epoch: 004 Step/Batch: 000000056 Step mean time: 3495ms
# Loss: 2.7580819 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:58:26 2018: Epoch: 004 Step/Batch: 000000057 Step mean time: 3507ms
# Loss: 2.6453447 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:58:32 2018: Epoch: 004 Step/Batch: 000000058 Step mean time: 3515ms
# Loss: 2.4445004 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 21:58:39 2018: Epoch: 004 Step/Batch: 000000059 Step mean time: 3523ms
# Loss: 2.6096020 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:58:45 2018: Epoch: 004 Step/Batch: 000000060 Step mean time: 3531ms
# Loss: 2.4636664 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:58:52 2018: Elapsed time: 0422ms --- Loss: 2.7139809 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 21:58:53 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 21:58:59 2018: Epoch: 004 Step/Batch: 000000061 Step mean time: 3538ms
# Loss: 2.7716193 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 21:59:05 2018: Epoch: 004 Step/Batch: 000000062 Step mean time: 3546ms
# Loss: 2.3697083 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 21:59:12 2018: Epoch: 004 Step/Batch: 000000063 Step mean time: 3553ms
# Loss: 2.5389876 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 21:59:18 2018: Epoch: 004 Step/Batch: 000000064 Step mean time: 3559ms
# Loss: 2.7608378 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:59:21 2018: Epoch: 004 Step/Batch: 000000065 Step mean time: 3536ms
# Loss: 2.3269563 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 21:59:29 2018: Elapsed time: 0458ms --- Loss: 2.8331461 Validation accuracy: 0.2000
# INFO:tensorflow:Sat Nov 17 21:59:35 2018: Epoch: 005 Step/Batch: 000000066 Step mean time: 3542ms
# Loss: 2.4423947 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 21:59:41 2018: Epoch: 005 Step/Batch: 000000067 Step mean time: 3550ms
# Loss: 2.8714728 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 21:59:48 2018: Epoch: 005 Step/Batch: 000000068 Step mean time: 3556ms
# Loss: 2.5451159 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 21:59:54 2018: Epoch: 005 Step/Batch: 000000069 Step mean time: 3562ms
# Loss: 2.6383920 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:00:00 2018: Epoch: 005 Step/Batch: 000000070 Step mean time: 3569ms
# Loss: 2.7514744 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:00:08 2018: Elapsed time: 0497ms --- Loss: 2.8245072 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 22:00:08 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:00:15 2018: Epoch: 005 Step/Batch: 000000071 Step mean time: 3574ms
# Loss: 2.4258773 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:00:21 2018: Epoch: 005 Step/Batch: 000000072 Step mean time: 3582ms
# Loss: 2.6983650 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:00:27 2018: Epoch: 005 Step/Batch: 000000073 Step mean time: 3587ms
# Loss: 2.5162396 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:00:34 2018: Epoch: 005 Step/Batch: 000000074 Step mean time: 3592ms
# Loss: 2.7142057 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:00:40 2018: Epoch: 005 Step/Batch: 000000075 Step mean time: 3598ms
# Loss: 2.4346991 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:00:48 2018: Elapsed time: 0537ms --- Loss: 2.6965408 Validation accuracy: 0.2000
# INFO:tensorflow:Sat Nov 17 22:00:54 2018: Epoch: 005 Step/Batch: 000000076 Step mean time: 3604ms
# Loss: 2.4880450 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:01:01 2018: Epoch: 005 Step/Batch: 000000077 Step mean time: 3611ms
# Loss: 2.6492667 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:01:04 2018: Epoch: 005 Step/Batch: 000000078 Step mean time: 3590ms
# Loss: 2.3752573 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:01:10 2018: Epoch: 006 Step/Batch: 000000079 Step mean time: 3596ms
# Loss: 2.4797015 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:01:17 2018: Epoch: 006 Step/Batch: 000000080 Step mean time: 3601ms
# Loss: 2.9043765 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:01:24 2018: Elapsed time: 0574ms --- Loss: 2.8569937 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 22:01:25 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:01:31 2018: Epoch: 006 Step/Batch: 000000081 Step mean time: 3607ms
# Loss: 2.9238803 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:01:38 2018: Epoch: 006 Step/Batch: 000000082 Step mean time: 3613ms
# Loss: 2.6950066 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:01:44 2018: Epoch: 006 Step/Batch: 000000083 Step mean time: 3617ms
# Loss: 2.6765561 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:01:50 2018: Epoch: 006 Step/Batch: 000000084 Step mean time: 3621ms
# Loss: 2.5164814 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:01:57 2018: Epoch: 006 Step/Batch: 000000085 Step mean time: 3625ms
# Loss: 2.5814030 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:02:04 2018: Elapsed time: 0614ms --- Loss: 2.7439618 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 22:02:11 2018: Epoch: 006 Step/Batch: 000000086 Step mean time: 3630ms
# Loss: 2.4737358 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:02:17 2018: Epoch: 006 Step/Batch: 000000087 Step mean time: 3636ms
# Loss: 2.7987335 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:02:24 2018: Epoch: 006 Step/Batch: 000000088 Step mean time: 3639ms
# Loss: 2.6318507 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:02:30 2018: Epoch: 006 Step/Batch: 000000089 Step mean time: 3642ms
# Loss: 2.6219537 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:02:36 2018: Epoch: 006 Step/Batch: 000000090 Step mean time: 3646ms
# Loss: 2.5636017 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:02:44 2018: Elapsed time: 0653ms --- Loss: 2.7182610 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 22:02:44 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:02:47 2018: Epoch: 006 Step/Batch: 000000091 Step mean time: 3628ms
# Loss: 2.3401279 Training accuracy: 0.6250
# INFO:tensorflow:Sat Nov 17 22:02:54 2018: Epoch: 007 Step/Batch: 000000092 Step mean time: 3634ms
# Loss: 2.5316083 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:03:00 2018: Epoch: 007 Step/Batch: 000000093 Step mean time: 3638ms
# Loss: 2.7304826 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:03:07 2018: Epoch: 007 Step/Batch: 000000094 Step mean time: 3642ms
# Loss: 2.5538230 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:03:13 2018: Epoch: 007 Step/Batch: 000000095 Step mean time: 3645ms
# Loss: 2.5843289 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:03:21 2018: Elapsed time: 0690ms --- Loss: 2.6657743 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:03:27 2018: Epoch: 007 Step/Batch: 000000096 Step mean time: 3649ms
# Loss: 2.5267506 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:03:34 2018: Epoch: 007 Step/Batch: 000000097 Step mean time: 3654ms
# Loss: 2.3343732 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:03:40 2018: Epoch: 007 Step/Batch: 000000098 Step mean time: 3658ms
# Loss: 2.4564426 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:03:47 2018: Epoch: 007 Step/Batch: 000000099 Step mean time: 3661ms
# Loss: 2.4843233 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:03:53 2018: Epoch: 007 Step/Batch: 000000100 Step mean time: 3665ms
# Loss: 2.4899526 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:04:00 2018: Elapsed time: 0730ms --- Loss: 2.6579428 Validation accuracy: 0.2000
# INFO:tensorflow:Sat Nov 17 22:04:01 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:04:07 2018: Epoch: 007 Step/Batch: 000000101 Step mean time: 3668ms
# Loss: 2.2520137 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:04:14 2018: Epoch: 007 Step/Batch: 000000102 Step mean time: 3672ms
# Loss: 2.4128916 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:04:20 2018: Epoch: 007 Step/Batch: 000000103 Step mean time: 3675ms
# Loss: 2.5946841 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:04:23 2018: Epoch: 007 Step/Batch: 000000104 Step mean time: 3660ms
# Loss: 2.0935414 Training accuracy: 0.6250
# INFO:tensorflow:Sat Nov 17 22:04:30 2018: Epoch: 008 Step/Batch: 000000105 Step mean time: 3663ms
# Loss: 2.2324808 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:04:37 2018: Elapsed time: 0767ms --- Loss: 2.7558215 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 22:04:44 2018: Epoch: 008 Step/Batch: 000000106 Step mean time: 3667ms
# Loss: 2.5826931 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:04:50 2018: Epoch: 008 Step/Batch: 000000107 Step mean time: 3671ms
# Loss: 2.5227475 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:04:57 2018: Epoch: 008 Step/Batch: 000000108 Step mean time: 3674ms
# Loss: 2.4524317 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:05:03 2018: Epoch: 008 Step/Batch: 000000109 Step mean time: 3678ms
# Loss: 2.4683962 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:05:09 2018: Epoch: 008 Step/Batch: 000000110 Step mean time: 3681ms
# Loss: 2.3315313 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:05:17 2018: Elapsed time: 0806ms --- Loss: 2.6418715 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 22:05:17 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:05:24 2018: Epoch: 008 Step/Batch: 000000111 Step mean time: 3685ms
# Loss: 2.4944539 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:05:30 2018: Epoch: 008 Step/Batch: 000000112 Step mean time: 3687ms
# Loss: 2.2773690 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:05:37 2018: Epoch: 008 Step/Batch: 000000113 Step mean time: 3690ms
# Loss: 2.6625381 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:05:43 2018: Epoch: 008 Step/Batch: 000000114 Step mean time: 3693ms
# Loss: 2.4503758 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:05:49 2018: Epoch: 008 Step/Batch: 000000115 Step mean time: 3696ms
# Loss: 2.5425816 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:05:57 2018: Elapsed time: 0846ms --- Loss: 2.6533449 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:06:03 2018: Epoch: 008 Step/Batch: 000000116 Step mean time: 3700ms
# Loss: 2.4835520 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:06:07 2018: Epoch: 008 Step/Batch: 000000117 Step mean time: 3687ms
# Loss: 2.1689000 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:06:13 2018: Epoch: 009 Step/Batch: 000000118 Step mean time: 3691ms
# Loss: 2.2463913 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:06:20 2018: Epoch: 009 Step/Batch: 000000119 Step mean time: 3694ms
# Loss: 2.8297532 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:06:26 2018: Epoch: 009 Step/Batch: 000000120 Step mean time: 3697ms
# Loss: 2.5368207 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:06:34 2018: Elapsed time: 0883ms --- Loss: 2.6707878 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 22:06:34 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:06:41 2018: Epoch: 009 Step/Batch: 000000121 Step mean time: 3699ms
# Loss: 2.5729218 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:06:47 2018: Epoch: 009 Step/Batch: 000000122 Step mean time: 3701ms
# Loss: 2.4978480 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:06:54 2018: Epoch: 009 Step/Batch: 000000123 Step mean time: 3705ms
# Loss: 2.2841041 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:07:00 2018: Epoch: 009 Step/Batch: 000000124 Step mean time: 3707ms
# Loss: 2.4581480 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:07:07 2018: Epoch: 009 Step/Batch: 000000125 Step mean time: 3710ms
# Loss: 2.3299441 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:07:14 2018: Elapsed time: 0923ms --- Loss: 2.6084833 Validation accuracy: 0.2200
# INFO:tensorflow:Sat Nov 17 22:07:21 2018: Epoch: 009 Step/Batch: 000000126 Step mean time: 3713ms
# Loss: 2.4574606 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:07:27 2018: Epoch: 009 Step/Batch: 000000127 Step mean time: 3715ms
# Loss: 2.4280684 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:07:34 2018: Epoch: 009 Step/Batch: 000000128 Step mean time: 3718ms
# Loss: 2.4707959 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:07:40 2018: Epoch: 009 Step/Batch: 000000129 Step mean time: 3720ms
# Loss: 2.5160172 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:07:43 2018: Epoch: 009 Step/Batch: 000000130 Step mean time: 3707ms
# Loss: 2.2471237 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:07:51 2018: Elapsed time: 0960ms --- Loss: 2.6606250 Validation accuracy: 0.2000
# INFO:tensorflow:Sat Nov 17 22:07:51 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:07:58 2018: Epoch: 010 Step/Batch: 000000131 Step mean time: 3710ms
# Loss: 2.2489183 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:08:04 2018: Epoch: 010 Step/Batch: 000000132 Step mean time: 3712ms
# Loss: 2.7381701 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:08:11 2018: Epoch: 010 Step/Batch: 000000133 Step mean time: 3716ms
# Loss: 2.4954691 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:08:17 2018: Epoch: 010 Step/Batch: 000000134 Step mean time: 3718ms
# Loss: 2.7026925 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:08:23 2018: Epoch: 010 Step/Batch: 000000135 Step mean time: 3720ms
# Loss: 2.4332185 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:08:31 2018: Elapsed time: 1000ms --- Loss: 2.6756315 Validation accuracy: 0.2000
# INFO:tensorflow:Sat Nov 17 22:08:38 2018: Epoch: 010 Step/Batch: 000000136 Step mean time: 3723ms
# Loss: 2.3594556 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:08:44 2018: Epoch: 010 Step/Batch: 000000137 Step mean time: 3725ms
# Loss: 2.4873087 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:08:51 2018: Epoch: 010 Step/Batch: 000000138 Step mean time: 3728ms
# Loss: 2.3006048 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:08:57 2018: Epoch: 010 Step/Batch: 000000139 Step mean time: 3730ms
# Loss: 2.5085175 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:09:03 2018: Epoch: 010 Step/Batch: 000000140 Step mean time: 3732ms
# Loss: 2.3389332 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:09:11 2018: Elapsed time: 1040ms --- Loss: 2.7149684 Validation accuracy: 0.1400
# INFO:tensorflow:Sat Nov 17 22:09:11 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:09:18 2018: Epoch: 010 Step/Batch: 000000141 Step mean time: 3734ms
# Loss: 2.4200194 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:09:24 2018: Epoch: 010 Step/Batch: 000000142 Step mean time: 3736ms
# Loss: 2.5775208 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:09:28 2018: Epoch: 010 Step/Batch: 000000143 Step mean time: 3724ms
# Loss: 2.2417314 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:09:34 2018: Epoch: 011 Step/Batch: 000000144 Step mean time: 3727ms
# Loss: 2.3331089 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:09:40 2018: Epoch: 011 Step/Batch: 000000145 Step mean time: 3729ms
# Loss: 2.4800084 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:09:48 2018: Elapsed time: 1077ms --- Loss: 2.6273179 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:09:54 2018: Epoch: 011 Step/Batch: 000000146 Step mean time: 3731ms
# Loss: 2.3050902 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:10:01 2018: Epoch: 011 Step/Batch: 000000147 Step mean time: 3733ms
# Loss: 2.4526148 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:10:07 2018: Epoch: 011 Step/Batch: 000000148 Step mean time: 3735ms
# Loss: 2.4311805 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:10:14 2018: Epoch: 011 Step/Batch: 000000149 Step mean time: 3737ms
# Loss: 2.2180057 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:10:20 2018: Epoch: 011 Step/Batch: 000000150 Step mean time: 3739ms
# Loss: 2.3831363 Training accuracy: 0.6250
# INFO:tensorflow:Sat Nov 17 22:10:28 2018: Elapsed time: 1117ms --- Loss: 2.6617303 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:10:28 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:10:35 2018: Epoch: 011 Step/Batch: 000000151 Step mean time: 3741ms
# Loss: 2.2092319 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:10:41 2018: Epoch: 011 Step/Batch: 000000152 Step mean time: 3743ms
# Loss: 2.5325694 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:10:48 2018: Epoch: 011 Step/Batch: 000000153 Step mean time: 3745ms
# Loss: 2.3917663 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:10:54 2018: Epoch: 011 Step/Batch: 000000154 Step mean time: 3747ms
# Loss: 2.3483217 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:11:00 2018: Epoch: 011 Step/Batch: 000000155 Step mean time: 3749ms
# Loss: 2.5267332 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:11:08 2018: Elapsed time: 1157ms --- Loss: 2.6203284 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:11:11 2018: Epoch: 011 Step/Batch: 000000156 Step mean time: 3739ms
# Loss: 2.0401917 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:11:18 2018: Epoch: 012 Step/Batch: 000000157 Step mean time: 3741ms
# Loss: 2.2705612 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:11:24 2018: Epoch: 012 Step/Batch: 000000158 Step mean time: 3743ms
# Loss: 2.5335381 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:11:31 2018: Epoch: 012 Step/Batch: 000000159 Step mean time: 3745ms
# Loss: 2.2306619 Training accuracy: 0.5625
# INFO:tensorflow:Sat Nov 17 22:11:37 2018: Epoch: 012 Step/Batch: 000000160 Step mean time: 3746ms
# Loss: 2.3777971 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:11:45 2018: Elapsed time: 1194ms --- Loss: 2.5993602 Validation accuracy: 0.2400
# INFO:tensorflow:Sat Nov 17 22:11:45 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:11:52 2018: Epoch: 012 Step/Batch: 000000161 Step mean time: 3748ms
# Loss: 2.4778850 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:11:58 2018: Epoch: 012 Step/Batch: 000000162 Step mean time: 3750ms
# Loss: 2.1140411 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:12:04 2018: Epoch: 012 Step/Batch: 000000163 Step mean time: 3752ms
# Loss: 2.3627450 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:12:11 2018: Epoch: 012 Step/Batch: 000000164 Step mean time: 3753ms
# Loss: 2.1699934 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:12:17 2018: Epoch: 012 Step/Batch: 000000165 Step mean time: 3755ms
# Loss: 2.4215224 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:12:25 2018: Elapsed time: 1234ms --- Loss: 2.6633806 Validation accuracy: 0.2000
# INFO:tensorflow:Sat Nov 17 22:12:31 2018: Epoch: 012 Step/Batch: 000000166 Step mean time: 3757ms
# Loss: 2.3186748 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:12:38 2018: Epoch: 012 Step/Batch: 000000167 Step mean time: 3758ms
# Loss: 2.2670033 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:12:44 2018: Epoch: 012 Step/Batch: 000000168 Step mean time: 3760ms
# Loss: 2.4368577 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:12:48 2018: Epoch: 012 Step/Batch: 000000169 Step mean time: 3751ms
# Loss: 2.0374455 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:12:54 2018: Epoch: 013 Step/Batch: 000000170 Step mean time: 3752ms
# Loss: 2.2835424 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:13:02 2018: Elapsed time: 1271ms --- Loss: 2.6225526 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:13:02 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:13:08 2018: Epoch: 013 Step/Batch: 000000171 Step mean time: 3753ms
# Loss: 2.9670117 Training accuracy: 0.0000
# INFO:tensorflow:Sat Nov 17 22:13:15 2018: Epoch: 013 Step/Batch: 000000172 Step mean time: 3755ms
# Loss: 2.5039356 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:13:21 2018: Epoch: 013 Step/Batch: 000000173 Step mean time: 3757ms
# Loss: 2.4985907 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:13:28 2018: Epoch: 013 Step/Batch: 000000174 Step mean time: 3759ms
# Loss: 2.4667552 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:13:34 2018: Epoch: 013 Step/Batch: 000000175 Step mean time: 3760ms
# Loss: 2.4033906 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:13:42 2018: Elapsed time: 1311ms --- Loss: 2.6164117 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 22:13:48 2018: Epoch: 013 Step/Batch: 000000176 Step mean time: 3762ms
# Loss: 2.3626304 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:13:55 2018: Epoch: 013 Step/Batch: 000000177 Step mean time: 3764ms
# Loss: 2.1822324 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:14:01 2018: Epoch: 013 Step/Batch: 000000178 Step mean time: 3765ms
# Loss: 2.6943378 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:14:08 2018: Epoch: 013 Step/Batch: 000000179 Step mean time: 3767ms
# Loss: 2.8334842 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:14:14 2018: Epoch: 013 Step/Batch: 000000180 Step mean time: 3769ms
# Loss: 2.4412100 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:14:22 2018: Elapsed time: 1351ms --- Loss: 2.7759907 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 22:14:22 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:14:28 2018: Epoch: 013 Step/Batch: 000000181 Step mean time: 3770ms
# Loss: 2.7797091 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:14:32 2018: Epoch: 013 Step/Batch: 000000182 Step mean time: 3760ms
# Loss: 1.9453022 Training accuracy: 0.6250
# INFO:tensorflow:Sat Nov 17 22:14:38 2018: Epoch: 014 Step/Batch: 000000183 Step mean time: 3762ms
# Loss: 2.3411729 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:14:45 2018: Epoch: 014 Step/Batch: 000000184 Step mean time: 3764ms
# Loss: 2.8634987 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:14:51 2018: Epoch: 014 Step/Batch: 000000185 Step mean time: 3765ms
# Loss: 2.6206827 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:14:59 2018: Elapsed time: 1388ms --- Loss: 2.6974773 Validation accuracy: 0.2000
# INFO:tensorflow:Sat Nov 17 22:15:05 2018: Epoch: 014 Step/Batch: 000000186 Step mean time: 3768ms
# Loss: 2.5622511 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:15:12 2018: Epoch: 014 Step/Batch: 000000187 Step mean time: 3769ms
# Loss: 2.5727000 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:15:18 2018: Epoch: 014 Step/Batch: 000000188 Step mean time: 3770ms
# Loss: 2.3190541 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:15:25 2018: Epoch: 014 Step/Batch: 000000189 Step mean time: 3772ms
# Loss: 2.5954483 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:15:31 2018: Epoch: 014 Step/Batch: 000000190 Step mean time: 3773ms
# Loss: 2.3586292 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:15:39 2018: Elapsed time: 1428ms --- Loss: 2.6091142 Validation accuracy: 0.1400
# INFO:tensorflow:Sat Nov 17 22:15:39 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:15:45 2018: Epoch: 014 Step/Batch: 000000191 Step mean time: 3774ms
# Loss: 2.6723709 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:15:52 2018: Epoch: 014 Step/Batch: 000000192 Step mean time: 3776ms
# Loss: 2.5594349 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:15:58 2018: Epoch: 014 Step/Batch: 000000193 Step mean time: 3777ms
# Loss: 2.3916221 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:16:05 2018: Epoch: 014 Step/Batch: 000000194 Step mean time: 3779ms
# Loss: 2.5807672 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:16:08 2018: Epoch: 014 Step/Batch: 000000195 Step mean time: 3770ms
# Loss: 2.2455461 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:16:16 2018: Elapsed time: 1465ms --- Loss: 2.6512380 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:16:22 2018: Epoch: 015 Step/Batch: 000000196 Step mean time: 3771ms
# Loss: 2.4056740 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:16:29 2018: Epoch: 015 Step/Batch: 000000197 Step mean time: 3773ms
# Loss: 2.6004884 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:16:35 2018: Epoch: 015 Step/Batch: 000000198 Step mean time: 3774ms
# Loss: 2.7516813 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:16:42 2018: Epoch: 015 Step/Batch: 000000199 Step mean time: 3775ms
# Loss: 2.4745657 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:16:48 2018: Epoch: 015 Step/Batch: 000000200 Step mean time: 3776ms
# Loss: 2.7644866 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:16:56 2018: Elapsed time: 1505ms --- Loss: 2.6311672 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 22:16:56 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:17:03 2018: Epoch: 015 Step/Batch: 000000201 Step mean time: 3778ms
# Loss: 2.4301338 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:17:09 2018: Epoch: 015 Step/Batch: 000000202 Step mean time: 3779ms
# Loss: 2.4905031 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:17:15 2018: Epoch: 015 Step/Batch: 000000203 Step mean time: 3780ms
# Loss: 2.5327902 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:17:22 2018: Epoch: 015 Step/Batch: 000000204 Step mean time: 3782ms
# Loss: 2.5888538 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:17:28 2018: Epoch: 015 Step/Batch: 000000205 Step mean time: 3783ms
# Loss: 2.6190963 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:17:36 2018: Elapsed time: 1545ms --- Loss: 2.6087756 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 22:17:43 2018: Epoch: 015 Step/Batch: 000000206 Step mean time: 3785ms
# Loss: 2.5062191 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:17:49 2018: Epoch: 015 Step/Batch: 000000207 Step mean time: 3786ms
# Loss: 2.4331830 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:17:52 2018: Epoch: 015 Step/Batch: 000000208 Step mean time: 3777ms
# Loss: 2.2480035 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:17:59 2018: Epoch: 016 Step/Batch: 000000209 Step mean time: 3778ms
# Loss: 2.5119944 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:18:05 2018: Epoch: 016 Step/Batch: 000000210 Step mean time: 3780ms
# Loss: 2.8988304 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:18:13 2018: Elapsed time: 1582ms --- Loss: 2.7718024 Validation accuracy: 0.0800
# INFO:tensorflow:Sat Nov 17 22:18:13 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:18:20 2018: Epoch: 016 Step/Batch: 000000211 Step mean time: 3781ms
# Loss: 3.0490012 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:18:26 2018: Epoch: 016 Step/Batch: 000000212 Step mean time: 3783ms
# Loss: 2.7710683 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:18:33 2018: Epoch: 016 Step/Batch: 000000213 Step mean time: 3784ms
# Loss: 3.0583961 Training accuracy: 0.0000
# INFO:tensorflow:Sat Nov 17 22:18:39 2018: Epoch: 016 Step/Batch: 000000214 Step mean time: 3785ms
# Loss: 2.8898468 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:18:46 2018: Epoch: 016 Step/Batch: 000000215 Step mean time: 3786ms
# Loss: 2.7969904 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:18:53 2018: Elapsed time: 1623ms --- Loss: 2.9198918 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:19:00 2018: Epoch: 016 Step/Batch: 000000216 Step mean time: 3788ms
# Loss: 2.8512876 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:19:06 2018: Epoch: 016 Step/Batch: 000000217 Step mean time: 3789ms
# Loss: 2.6750612 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:19:13 2018: Epoch: 016 Step/Batch: 000000218 Step mean time: 3790ms
# Loss: 2.8269515 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:19:19 2018: Epoch: 016 Step/Batch: 000000219 Step mean time: 3792ms
# Loss: 2.7568669 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:19:26 2018: Epoch: 016 Step/Batch: 000000220 Step mean time: 3793ms
# Loss: 2.8549402 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:19:33 2018: Elapsed time: 1663ms --- Loss: 2.8670721 Validation accuracy: 0.2000
# INFO:tensorflow:Sat Nov 17 22:19:34 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:19:37 2018: Epoch: 016 Step/Batch: 000000221 Step mean time: 3785ms
# Loss: 2.4579611 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:19:43 2018: Epoch: 017 Step/Batch: 000000222 Step mean time: 3786ms
# Loss: 2.9662337 Training accuracy: 0.0000
# INFO:tensorflow:Sat Nov 17 22:19:50 2018: Epoch: 017 Step/Batch: 000000223 Step mean time: 3787ms
# Loss: 2.5118675 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:19:56 2018: Epoch: 017 Step/Batch: 000000224 Step mean time: 3789ms
# Loss: 2.8501091 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:20:02 2018: Epoch: 017 Step/Batch: 000000225 Step mean time: 3790ms
# Loss: 2.8859880 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:20:10 2018: Elapsed time: 1699ms --- Loss: 3.0250182 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 22:20:17 2018: Epoch: 017 Step/Batch: 000000226 Step mean time: 3791ms
# Loss: 2.9547338 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:20:23 2018: Epoch: 017 Step/Batch: 000000227 Step mean time: 3792ms
# Loss: 2.9690895 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:20:30 2018: Epoch: 017 Step/Batch: 000000228 Step mean time: 3793ms
# Loss: 2.7196977 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:20:37 2018: Epoch: 017 Step/Batch: 000000229 Step mean time: 3796ms
# Loss: 3.1119795 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:20:44 2018: Epoch: 017 Step/Batch: 000000230 Step mean time: 3798ms
# Loss: 2.8036423 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:20:52 2018: Elapsed time: 1742ms --- Loss: 2.9756742 Validation accuracy: 0.0600
# INFO:tensorflow:Sat Nov 17 22:20:53 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:21:00 2018: Epoch: 017 Step/Batch: 000000231 Step mean time: 3801ms
# Loss: 2.6840250 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:21:06 2018: Epoch: 017 Step/Batch: 000000232 Step mean time: 3802ms
# Loss: 2.6711912 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:21:13 2018: Epoch: 017 Step/Batch: 000000233 Step mean time: 3803ms
# Loss: 2.8363752 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:21:16 2018: Epoch: 017 Step/Batch: 000000234 Step mean time: 3797ms
# Loss: 2.5147572 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:21:23 2018: Epoch: 018 Step/Batch: 000000235 Step mean time: 3799ms
# Loss: 2.4058759 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:21:32 2018: Elapsed time: 1781ms --- Loss: 2.8273513 Validation accuracy: 0.1000
# INFO:tensorflow:Sat Nov 17 22:21:39 2018: Epoch: 018 Step/Batch: 000000236 Step mean time: 3802ms
# Loss: 2.8508625 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:21:46 2018: Epoch: 018 Step/Batch: 000000237 Step mean time: 3804ms
# Loss: 3.0848379 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:21:52 2018: Epoch: 018 Step/Batch: 000000238 Step mean time: 3805ms
# Loss: 2.9869874 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:21:59 2018: Epoch: 018 Step/Batch: 000000239 Step mean time: 3806ms
# Loss: 2.8664820 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:22:06 2018: Epoch: 018 Step/Batch: 000000240 Step mean time: 3808ms
# Loss: 2.9326091 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:22:14 2018: Elapsed time: 1823ms --- Loss: 2.9662271 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 22:22:14 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:22:21 2018: Epoch: 018 Step/Batch: 000000241 Step mean time: 3809ms
# Loss: 2.9166558 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:22:27 2018: Epoch: 018 Step/Batch: 000000242 Step mean time: 3810ms
# Loss: 2.7443302 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:22:34 2018: Epoch: 018 Step/Batch: 000000243 Step mean time: 3812ms
# Loss: 2.6956911 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:22:41 2018: Epoch: 018 Step/Batch: 000000244 Step mean time: 3815ms
# Loss: 2.5259109 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:22:49 2018: Epoch: 018 Step/Batch: 000000245 Step mean time: 3817ms
# Loss: 2.5167575 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:22:57 2018: Elapsed time: 1867ms --- Loss: 2.8085332 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 22:23:04 2018: Epoch: 018 Step/Batch: 000000246 Step mean time: 3820ms
# Loss: 2.7573862 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:23:08 2018: Epoch: 018 Step/Batch: 000000247 Step mean time: 3813ms
# Loss: 2.3282218 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:23:15 2018: Epoch: 019 Step/Batch: 000000248 Step mean time: 3815ms
# Loss: 2.5945256 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:23:21 2018: Epoch: 019 Step/Batch: 000000249 Step mean time: 3816ms
# Loss: 2.8014071 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:23:28 2018: Epoch: 019 Step/Batch: 000000250 Step mean time: 3818ms
# Loss: 2.7224104 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:23:36 2018: Elapsed time: 1906ms --- Loss: 2.8689637 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 22:23:37 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:23:44 2018: Epoch: 019 Step/Batch: 000000251 Step mean time: 3820ms
# Loss: 2.6461785 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:23:50 2018: Epoch: 019 Step/Batch: 000000252 Step mean time: 3821ms
# Loss: 2.7500973 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:23:57 2018: Epoch: 019 Step/Batch: 000000253 Step mean time: 3823ms
# Loss: 2.6771371 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:24:04 2018: Epoch: 019 Step/Batch: 000000254 Step mean time: 3825ms
# Loss: 2.7272243 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:24:11 2018: Epoch: 019 Step/Batch: 000000255 Step mean time: 3826ms
# Loss: 2.6662180 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:24:18 2018: Elapsed time: 1948ms --- Loss: 2.7875168 Validation accuracy: 0.1400
# INFO:tensorflow:Sat Nov 17 22:24:25 2018: Epoch: 019 Step/Batch: 000000256 Step mean time: 3827ms
# Loss: 2.7992742 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:24:31 2018: Epoch: 019 Step/Batch: 000000257 Step mean time: 3828ms
# Loss: 2.5908761 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:24:38 2018: Epoch: 019 Step/Batch: 000000258 Step mean time: 3828ms
# Loss: 2.6309776 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:24:44 2018: Epoch: 019 Step/Batch: 000000259 Step mean time: 3829ms
# Loss: 2.7312872 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:24:47 2018: Epoch: 019 Step/Batch: 000000260 Step mean time: 3822ms
# Loss: 2.4982741 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:24:55 2018: Elapsed time: 1984ms --- Loss: 2.6933255 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:24:55 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:25:02 2018: Epoch: 020 Step/Batch: 000000261 Step mean time: 3823ms
# Loss: 2.5369699 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:25:08 2018: Epoch: 020 Step/Batch: 000000262 Step mean time: 3823ms
# Loss: 2.7909765 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:25:15 2018: Epoch: 020 Step/Batch: 000000263 Step mean time: 3824ms
# Loss: 2.7312598 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:25:21 2018: Epoch: 020 Step/Batch: 000000264 Step mean time: 3825ms
# Loss: 2.6990380 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:25:28 2018: Epoch: 020 Step/Batch: 000000265 Step mean time: 3826ms
# Loss: 2.6019888 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:25:35 2018: Elapsed time: 2025ms --- Loss: 2.6500814 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 22:25:42 2018: Epoch: 020 Step/Batch: 000000266 Step mean time: 3827ms
# Loss: 2.6267579 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:25:49 2018: Epoch: 020 Step/Batch: 000000267 Step mean time: 3829ms
# Loss: 2.7150648 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:25:56 2018: Epoch: 020 Step/Batch: 000000268 Step mean time: 3831ms
# Loss: 2.6106422 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:26:03 2018: Epoch: 020 Step/Batch: 000000269 Step mean time: 3832ms
# Loss: 2.6814766 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:26:10 2018: Epoch: 020 Step/Batch: 000000270 Step mean time: 3835ms
# Loss: 2.4854002 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:26:19 2018: Elapsed time: 2068ms --- Loss: 2.7219243 Validation accuracy: 0.0800
# INFO:tensorflow:Sat Nov 17 22:26:19 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:26:26 2018: Epoch: 020 Step/Batch: 000000271 Step mean time: 3838ms
# Loss: 2.6438103 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:26:33 2018: Epoch: 020 Step/Batch: 000000272 Step mean time: 3840ms
# Loss: 2.5903268 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:26:37 2018: Epoch: 020 Step/Batch: 000000273 Step mean time: 3834ms
# Loss: 2.3995504 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:26:44 2018: Epoch: 021 Step/Batch: 000000274 Step mean time: 3837ms
# Loss: 2.3174219 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:26:51 2018: Epoch: 021 Step/Batch: 000000275 Step mean time: 3839ms
# Loss: 2.8177369 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:26:59 2018: Elapsed time: 2108ms --- Loss: 2.7890112 Validation accuracy: 0.1400
# INFO:tensorflow:Sat Nov 17 22:27:06 2018: Epoch: 021 Step/Batch: 000000276 Step mean time: 3840ms
# Loss: 2.7941816 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:27:12 2018: Epoch: 021 Step/Batch: 000000277 Step mean time: 3840ms
# Loss: 2.5544338 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:27:19 2018: Epoch: 021 Step/Batch: 000000278 Step mean time: 3843ms
# Loss: 2.6870806 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:27:26 2018: Epoch: 021 Step/Batch: 000000279 Step mean time: 3843ms
# Loss: 2.5703869 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:27:33 2018: Epoch: 021 Step/Batch: 000000280 Step mean time: 3846ms
# Loss: 2.6069748 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:27:41 2018: Elapsed time: 2151ms --- Loss: 2.8025424 Validation accuracy: 0.1000
# INFO:tensorflow:Sat Nov 17 22:27:42 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:27:49 2018: Epoch: 021 Step/Batch: 000000281 Step mean time: 3847ms
# Loss: 2.6157713 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:27:55 2018: Epoch: 021 Step/Batch: 000000282 Step mean time: 3848ms
# Loss: 2.8078771 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:28:02 2018: Epoch: 021 Step/Batch: 000000283 Step mean time: 3852ms
# Loss: 2.6019752 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:28:09 2018: Epoch: 021 Step/Batch: 000000284 Step mean time: 3852ms
# Loss: 2.6359341 Training accuracy: 0.3125
# ...
# Loss: 2.4096975 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:30:01 2018: Epoch: 022 Step/Batch: 000000297 Step mean time: 3861ms
# Loss: 2.5106859 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:30:08 2018: Epoch: 022 Step/Batch: 000000298 Step mean time: 3862ms
# Loss: 2.6061537 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:30:12 2018: Epoch: 022 Step/Batch: 000000299 Step mean time: 3856ms
# Loss: 2.2869697 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:30:19 2018: Epoch: 023 Step/Batch: 000000300 Step mean time: 3859ms
# Loss: 2.2769694 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:30:30 2018: Elapsed time: 2319ms --- Loss: 2.7084999 Validation accuracy: 0.2400
# INFO:tensorflow:Sat Nov 17 22:30:30 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:30:40 2018: Epoch: 023 Step/Batch: 000000301 Step mean time: 3866ms
# Loss: 2.5428152 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:30:49 2018: Epoch: 023 Step/Batch: 000000302 Step mean time: 3873ms
# Loss: 2.5220094 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:30:57 2018: Epoch: 023 Step/Batch: 000000303 Step mean time: 3874ms
# Loss: 2.4599106 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:31:04 2018: Epoch: 023 Step/Batch: 000000304 Step mean time: 3876ms
# Loss: 2.5530083 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:31:13 2018: Epoch: 023 Step/Batch: 000000305 Step mean time: 3881ms
# Loss: 2.4491589 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:31:25 2018: Elapsed time: 2374ms --- Loss: 2.7100618 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 22:31:36 2018: Epoch: 023 Step/Batch: 000000306 Step mean time: 3891ms
# Loss: 2.5319042 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:31:45 2018: Epoch: 023 Step/Batch: 000000307 Step mean time: 3895ms
# Loss: 2.7907917 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:31:55 2018: Epoch: 023 Step/Batch: 000000308 Step mean time: 3902ms
# Loss: 2.7204835 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:32:06 2018: Epoch: 023 Step/Batch: 000000309 Step mean time: 3911ms
# Loss: 2.7090218 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:32:17 2018: Epoch: 023 Step/Batch: 000000310 Step mean time: 3921ms
# Loss: 2.8923039 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:32:29 2018: Elapsed time: 2439ms --- Loss: 2.8851008 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:32:30 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:32:41 2018: Epoch: 023 Step/Batch: 000000311 Step mean time: 3931ms
# Loss: 2.5470142 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:32:46 2018: Epoch: 023 Step/Batch: 000000312 Step mean time: 3928ms
# Loss: 2.2154281 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:32:57 2018: Epoch: 024 Step/Batch: 000000313 Step mean time: 3937ms
# Loss: 2.2697330 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:33:07 2018: Epoch: 024 Step/Batch: 000000314 Step mean time: 3944ms
# Loss: 2.5924981 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:33:17 2018: Epoch: 024 Step/Batch: 000000315 Step mean time: 3951ms
# Loss: 2.7627680 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:33:30 2018: Elapsed time: 2499ms --- Loss: 2.6597126 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:33:39 2018: Epoch: 024 Step/Batch: 000000316 Step mean time: 3957ms
# Loss: 2.3844042 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:33:49 2018: Epoch: 024 Step/Batch: 000000317 Step mean time: 3964ms
# Loss: 2.8827841 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:33:59 2018: Epoch: 024 Step/Batch: 000000318 Step mean time: 3970ms
# Loss: 2.8001888 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:34:09 2018: Epoch: 024 Step/Batch: 000000319 Step mean time: 3977ms
# Loss: 2.9336970 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:34:20 2018: Epoch: 024 Step/Batch: 000000320 Step mean time: 3987ms
# Loss: 2.6362784 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:34:29 2018: Elapsed time: 2558ms --- Loss: 2.6643574 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:34:29 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:34:36 2018: Epoch: 024 Step/Batch: 000000321 Step mean time: 3987ms
# Loss: 2.5986807 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:34:43 2018: Epoch: 024 Step/Batch: 000000322 Step mean time: 3988ms
# Loss: 2.6802139 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:34:49 2018: Epoch: 024 Step/Batch: 000000323 Step mean time: 3988ms
# Loss: 2.6524913 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:34:56 2018: Epoch: 024 Step/Batch: 000000324 Step mean time: 3989ms
# Loss: 2.6907072 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:34:59 2018: Epoch: 024 Step/Batch: 000000325 Step mean time: 3983ms
# Loss: 2.4470417 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:35:07 2018: Elapsed time: 2596ms --- Loss: 2.7120707 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 22:35:15 2018: Epoch: 025 Step/Batch: 000000326 Step mean time: 3984ms
# Loss: 2.4771652 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:35:22 2018: Epoch: 025 Step/Batch: 000000327 Step mean time: 3986ms
# Loss: 2.7010691 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:35:28 2018: Epoch: 025 Step/Batch: 000000328 Step mean time: 3987ms
# Loss: 2.8630974 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:35:35 2018: Epoch: 025 Step/Batch: 000000329 Step mean time: 3987ms
# Loss: 2.7293603 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:35:42 2018: Epoch: 025 Step/Batch: 000000330 Step mean time: 3987ms
# Loss: 2.6173813 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:35:50 2018: Elapsed time: 2639ms --- Loss: 2.7200892 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:35:50 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:35:56 2018: Epoch: 025 Step/Batch: 000000331 Step mean time: 3988ms
# Loss: 2.8160884 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:36:03 2018: Epoch: 025 Step/Batch: 000000332 Step mean time: 3988ms
# Loss: 2.9177012 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:36:11 2018: Epoch: 025 Step/Batch: 000000333 Step mean time: 3990ms
# Loss: 2.8561335 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:36:18 2018: Epoch: 025 Step/Batch: 000000334 Step mean time: 3991ms
# Loss: 2.6226103 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:36:24 2018: Epoch: 025 Step/Batch: 000000335 Step mean time: 3991ms
# Loss: 2.8877876 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:36:33 2018: Elapsed time: 2682ms --- Loss: 2.8382378 Validation accuracy: 0.1000
# INFO:tensorflow:Sat Nov 17 22:36:41 2018: Epoch: 025 Step/Batch: 000000336 Step mean time: 3994ms
# Loss: 2.4094982 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:36:48 2018: Epoch: 025 Step/Batch: 000000337 Step mean time: 3996ms
# Loss: 3.4101605 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:36:51 2018: Epoch: 025 Step/Batch: 000000338 Step mean time: 3991ms
# Loss: 2.3700781 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:36:58 2018: Epoch: 026 Step/Batch: 000000339 Step mean time: 3991ms
# Loss: 2.5676286 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:37:05 2018: Epoch: 026 Step/Batch: 000000340 Step mean time: 3992ms
# Loss: 2.5201826 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:37:13 2018: Elapsed time: 2722ms --- Loss: 2.8448243 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 22:37:13 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:37:20 2018: Epoch: 026 Step/Batch: 000000341 Step mean time: 3992ms
# Loss: 2.7466159 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:37:27 2018: Epoch: 026 Step/Batch: 000000342 Step mean time: 3994ms
# Loss: 2.4887640 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:37:34 2018: Epoch: 026 Step/Batch: 000000343 Step mean time: 3995ms
# Loss: 2.6951802 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:37:41 2018: Epoch: 026 Step/Batch: 000000344 Step mean time: 3996ms
# Loss: 2.7290015 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:37:48 2018: Epoch: 026 Step/Batch: 000000345 Step mean time: 3996ms
# Loss: 2.7949762 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:37:56 2018: Elapsed time: 2765ms --- Loss: 2.8094497 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 22:38:03 2018: Epoch: 026 Step/Batch: 000000346 Step mean time: 3997ms
# Loss: 2.7280967 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:38:09 2018: Epoch: 026 Step/Batch: 000000347 Step mean time: 3997ms
# Loss: 2.7356186 Training accuracy: 0.0000
# INFO:tensorflow:Sat Nov 17 22:38:16 2018: Epoch: 026 Step/Batch: 000000348 Step mean time: 3999ms
# Loss: 2.4746809 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:38:24 2018: Epoch: 026 Step/Batch: 000000349 Step mean time: 4000ms
# Loss: 2.3732843 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:38:31 2018: Epoch: 026 Step/Batch: 000000350 Step mean time: 4002ms
# Loss: 2.7806575 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:38:40 2018: Elapsed time: 2809ms --- Loss: 2.7342360 Validation accuracy: 0.1200
# INFO:tensorflow:Sat Nov 17 22:38:41 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:38:44 2018: Epoch: 026 Step/Batch: 000000351 Step mean time: 3997ms
# Loss: 2.2994444 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:38:52 2018: Epoch: 027 Step/Batch: 000000352 Step mean time: 3999ms
# Loss: 2.3397269 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:38:59 2018: Epoch: 027 Step/Batch: 000000353 Step mean time: 4001ms
# Loss: 2.6854174 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:39:06 2018: Epoch: 027 Step/Batch: 000000354 Step mean time: 4002ms
# Loss: 2.9435880 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:39:13 2018: Epoch: 027 Step/Batch: 000000355 Step mean time: 4003ms
# Loss: 2.5443659 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:39:23 2018: Elapsed time: 2853ms --- Loss: 2.7351000 Validation accuracy: 0.2000
# INFO:tensorflow:Sat Nov 17 22:39:32 2018: Epoch: 027 Step/Batch: 000000356 Step mean time: 4007ms
# Loss: 2.7138562 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:39:42 2018: Epoch: 027 Step/Batch: 000000357 Step mean time: 4014ms
# Loss: 2.5814826 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:39:50 2018: Epoch: 027 Step/Batch: 000000358 Step mean time: 4017ms
# Loss: 2.6421065 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:39:57 2018: Epoch: 027 Step/Batch: 000000359 Step mean time: 4018ms
# Loss: 2.6669149 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:40:04 2018: Epoch: 027 Step/Batch: 000000360 Step mean time: 4018ms
# Loss: 2.7048764 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:40:12 2018: Elapsed time: 2902ms --- Loss: 2.7115250 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:40:13 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:40:20 2018: Epoch: 027 Step/Batch: 000000361 Step mean time: 4020ms
# Loss: 2.4476905 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:40:28 2018: Epoch: 027 Step/Batch: 000000362 Step mean time: 4022ms
# Loss: 2.5054207 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:40:35 2018: Epoch: 027 Step/Batch: 000000363 Step mean time: 4024ms
# Loss: 2.7219973 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:40:39 2018: Epoch: 027 Step/Batch: 000000364 Step mean time: 4019ms
# Loss: 2.2515426 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:40:47 2018: Epoch: 028 Step/Batch: 000000365 Step mean time: 4021ms
# Loss: 2.3421118 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:40:56 2018: Elapsed time: 2945ms --- Loss: 2.6630752 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 22:41:03 2018: Epoch: 028 Step/Batch: 000000366 Step mean time: 4023ms
# Loss: 2.4513750 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:41:10 2018: Epoch: 028 Step/Batch: 000000367 Step mean time: 4024ms
# Loss: 2.6858318 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:41:18 2018: Epoch: 028 Step/Batch: 000000368 Step mean time: 4025ms
# Loss: 2.5353322 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:41:25 2018: Epoch: 028 Step/Batch: 000000369 Step mean time: 4027ms
# Loss: 2.6095524 Training accuracy: 0.0625
# INFO:tensorflow:Sat Nov 17 22:41:33 2018: Epoch: 028 Step/Batch: 000000370 Step mean time: 4028ms
# Loss: 2.4727907 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:41:41 2018: Elapsed time: 2991ms --- Loss: 2.6103816 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 22:41:42 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:41:49 2018: Epoch: 028 Step/Batch: 000000371 Step mean time: 4029ms
# Loss: 2.5562706 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:41:56 2018: Epoch: 028 Step/Batch: 000000372 Step mean time: 4031ms
# Loss: 2.5372643 Training accuracy: 0.1875
# INFO:tensorflow:Sat Nov 17 22:42:05 2018: Epoch: 028 Step/Batch: 000000373 Step mean time: 4035ms
# Loss: 2.5053377 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:42:12 2018: Epoch: 028 Step/Batch: 000000374 Step mean time: 4037ms
# Loss: 2.2886577 Training accuracy: 0.4375
# INFO:tensorflow:Sat Nov 17 22:42:19 2018: Epoch: 028 Step/Batch: 000000375 Step mean time: 4038ms
# Loss: 2.4576073 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:42:28 2018: Elapsed time: 3037ms --- Loss: 2.6008432 Validation accuracy: 0.2200
# INFO:tensorflow:Sat Nov 17 22:42:36 2018: Epoch: 028 Step/Batch: 000000376 Step mean time: 4042ms
# Loss: 2.6554463 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:42:40 2018: Epoch: 028 Step/Batch: 000000377 Step mean time: 4037ms
# Loss: 2.2697568 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:42:48 2018: Epoch: 029 Step/Batch: 000000378 Step mean time: 4039ms
# Loss: 2.1682088 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:42:55 2018: Epoch: 029 Step/Batch: 000000379 Step mean time: 4040ms
# Loss: 2.4305947 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:43:02 2018: Epoch: 029 Step/Batch: 000000380 Step mean time: 4042ms
# Loss: 2.5675402 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:43:11 2018: Elapsed time: 3080ms --- Loss: 2.6507740 Validation accuracy: 0.2000
# INFO:tensorflow:Sat Nov 17 22:43:11 2018: Variables saved
# INFO:tensorflow:Sat Nov 17 22:43:19 2018: Epoch: 029 Step/Batch: 000000381 Step mean time: 4043ms
# Loss: 2.4459419 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:43:26 2018: Epoch: 029 Step/Batch: 000000382 Step mean time: 4044ms
# Loss: 2.5501168 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:43:33 2018: Epoch: 029 Step/Batch: 000000383 Step mean time: 4045ms
# Loss: 2.4605052 Training accuracy: 0.2500
# INFO:tensorflow:Sat Nov 17 22:43:40 2018: Epoch: 029 Step/Batch: 000000384 Step mean time: 4047ms
# Loss: 2.5799563 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:43:48 2018: Epoch: 029 Step/Batch: 000000385 Step mean time: 4048ms
# Loss: 2.4139504 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:43:56 2018: Elapsed time: 3126ms --- Loss: 2.6885114 Validation accuracy: 0.1600
# INFO:tensorflow:Sat Nov 17 22:44:04 2018: Epoch: 029 Step/Batch: 000000386 Step mean time: 4049ms
# Loss: 2.4243665 Training accuracy: 0.3125
# INFO:tensorflow:Sat Nov 17 22:44:10 2018: Epoch: 029 Step/Batch: 000000387 Step mean time: 4050ms
# Loss: 2.2558923 Training accuracy: 0.5000
# INFO:tensorflow:Sat Nov 17 22:44:17 2018: Epoch: 029 Step/Batch: 000000388 Step mean time: 4050ms
# Loss: 2.5222726 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:44:24 2018: Epoch: 029 Step/Batch: 000000389 Step mean time: 4051ms
# Loss: 2.6818419 Training accuracy: 0.1250
# INFO:tensorflow:Sat Nov 17 22:44:28 2018: Epoch: 029 Step/Batch: 000000390 Step mean time: 4046ms
# Loss: 2.2084906 Training accuracy: 0.3750
# INFO:tensorflow:Sat Nov 17 22:44:36 2018: Elapsed time: 3166ms --- Loss: 2.6327643 Validation accuracy: 0.1800
# INFO:tensorflow:Sat Nov 17 22:44:37 2018: Variables saved

# %%
for (_, (test_images, test_labels)) in enumerate(test_dset):
    l = loss(alexnet, 'val', test_images, test_labels)
    a = accuracy(alexnet, 'val', test_images, test_labels).numpy()
log_msg('Final Test Loss: {:.7f} Test accuracy: {:.4f}'.format(l, a))
